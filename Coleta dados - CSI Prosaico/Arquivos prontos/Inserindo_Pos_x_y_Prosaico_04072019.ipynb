# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
csidf = pd.read_excel("subcarriers_amp_pos_pot.xlsx", sheet_name="subcarriers_amp_pos_pot")
csidf.drop("Unnamed: 0", axis=1, inplace=True)
csidf.head()
# Out:
#   device local  x  y  P_MW_LLTF  P_MW_HTLTF  P_DBM_LLTF  P_DBM_HTLTF  \
# 0    DIR    A1  1  3         68        1763   18.326305    32.462711
# 1    DIR    A1  1  3         91        2902   19.625982    34.627993
# 2    DIR    A1  1  3         79        1819   19.009755    32.599737
# 3    DIR    A1  1  3         82        2482   19.157725    33.949590
# 4    DIR    A1  1  3         43         736   16.433430    28.670187
#
#    LLTF_-32  LLTF_-31  ...   HTLTF_22   HTLTF_23   HTLTF_24   HTLTF_25  \
# 0         0         0  ...  22.090722  19.000000  17.029386  15.132746
# 1         0         0  ...  24.083189  22.203603  19.416488  17.720045
# 2         0         0  ...  21.023796  18.110770  17.464249  15.811388
# 3         0         0  ...  21.954498  19.416488  17.029386  15.556349
# 4         0         0  ...  20.000000  17.492856  15.231546  13.601471
#
#     HTLTF_26   HTLTF_27   HTLTF_28  HTLTF_29  HTLTF_30  HTLTF_31
# ...

# %%
for x in csidf.index:
    if csidf["local"].loc[x]=="A1":
        csidf['x'][x] = 1
        csidf['y'][x] = 6.05
    if csidf["local"].loc[x]=="A2":
        csidf['x'][x] = 0.7
        csidf['y'][x] = 4.12
    if csidf["local"].loc[x]=="A3":
        csidf['x'][x] = 0.7
        csidf['y'][x] = 1.2
    if csidf["local"].loc[x]=="B1":
        csidf['x'][x] = 2.15
        csidf['y'][x] = 6.05
    if csidf["local"].loc[x]=="B2":
        csidf['x'][x] = 2.55
        csidf['y'][x] = 4.12
    if csidf["local"].loc[x]=="B3":
        csidf['x'][x] = 2.55
        csidf['y'][x] = 1.2
    if csidf["local"].loc[x]=="D1":
        csidf['x'][x] = 4.85
        csidf['y'][x] = 5.8
    if csidf["local"].loc[x]=="D2":
        csidf['x'][x] = 4.85
        csidf['y'][x] = 4
    if csidf["local"].loc[x]=="D3":
        csidf['x'][x] = 4.85
        csidf['y'][x] = 1.2
    if csidf["local"].loc[x]=="E1":
        csidf['x'][x] = 7.35
        csidf['y'][x] = 6.55
    if csidf["local"].loc[x]=="E2":
        csidf['x'][x] = 7.35
        csidf['y'][x] = 4.12
    if csidf["local"].loc[x]=="E3":
        csidf['x'][x] = 7.35
        csidf['y'][x] = 1.5
# Out:
# C:\Users\iande\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\iande\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\iande\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
csidf.head()
# Out:
#   device local    x     y  P_MW_LLTF  P_MW_HTLTF  P_DBM_LLTF  P_DBM_HTLTF  \
# 0    DIR    A1  1.0  6.05         68        1763   18.326305    32.462711
# 1    DIR    A1  1.0  6.05         91        2902   19.625982    34.627993
# 2    DIR    A1  1.0  6.05         79        1819   19.009755    32.599737
# 3    DIR    A1  1.0  6.05         82        2482   19.157725    33.949590
# 4    DIR    A1  1.0  6.05         43         736   16.433430    28.670187
#
#    LLTF_-32  LLTF_-31  ...   HTLTF_22   HTLTF_23   HTLTF_24   HTLTF_25  \
# 0         0         0  ...  22.090722  19.000000  17.029386  15.132746
# 1         0         0  ...  24.083189  22.203603  19.416488  17.720045
# 2         0         0  ...  21.023796  18.110770  17.464249  15.811388
# 3         0         0  ...  21.954498  19.416488  17.029386  15.556349
# 4         0         0  ...  20.000000  17.492856  15.231546  13.601471
#
#     HTLTF_26   HTLTF_27   HTLTF_28  HTLTF_29  HTLTF_30  HTLTF_31
# ...

# %%
csidf[csidf["local"]=="E2"]
# Out:
#      device local     x     y  P_MW_LLTF  P_MW_HTLTF  P_DBM_LLTF  P_DBM_HTLTF  \
# 400     DIR    E2  7.35  4.12         77        2014   18.908656    33.040777
# 401     DIR    E2  7.35  4.12         72        1904   18.624242    32.798873
# 402     DIR    E2  7.35  4.12         68        1530   18.376097    31.847691
# 403     DIR    E2  7.35  4.12         69        1766   18.389093    32.472251
# 404     DIR    E2  7.35  4.12        112        3759   20.500187    35.750743
# 405     DIR    E2  7.35  4.12         68        1579   18.348796    31.986125
# 406     DIR    E2  7.35  4.12         84        2313   19.271400    33.641819
# 407     DIR    E2  7.35  4.12         93        2246   19.690021    33.514597
# 408     DIR    E2  7.35  4.12         57        1127   17.580742    30.522341
# 409     DIR    E2  7.35  4.12        100        2866   20.041426    34.573403
# 410     DIR    E2  7.35  4.12         99        2642   19.978278    34.220876
# ...

# %%
csidf.to_excel("subcarriers_amp_pos_pot.xlsx", sheet_name="subcarriers_amp_pos_pot")

# %%
csidf_teste = pd.read_excel("subcarriers_amp_pos_pot.xlsx", sheet_name="subcarriers_amp_pos_pot")
csidf_teste.drop("Unnamed: 0", axis=1, inplace=True)
csidf_teste.head()
# Out:
#   device local    x     y  P_MW_LLTF  P_MW_HTLTF  P_DBM_LLTF  P_DBM_HTLTF  \
# 0    DIR    A1  1.0  6.05         68        1763   18.326305    32.462711
# 1    DIR    A1  1.0  6.05         91        2902   19.625982    34.627993
# 2    DIR    A1  1.0  6.05         79        1819   19.009755    32.599737
# 3    DIR    A1  1.0  6.05         82        2482   19.157725    33.949590
# 4    DIR    A1  1.0  6.05         43         736   16.433430    28.670187
#
#    LLTF_-32  LLTF_-31  ...   HTLTF_22   HTLTF_23   HTLTF_24   HTLTF_25  \
# 0         0         0  ...  22.090722  19.000000  17.029386  15.132746
# 1         0         0  ...  24.083189  22.203603  19.416488  17.720045
# 2         0         0  ...  21.023796  18.110770  17.464249  15.811388
# 3         0         0  ...  21.954498  19.416488  17.029386  15.556349
# 4         0         0  ...  20.000000  17.492856  15.231546  13.601471
#
#     HTLTF_26   HTLTF_27   HTLTF_28  HTLTF_29  HTLTF_30  HTLTF_31
# ...
